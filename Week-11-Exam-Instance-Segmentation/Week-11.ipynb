# %% [markdown]
# # Week 11: Exam and Instance Segmentation

# %% [markdown]
# ## Week 11 Meetings
#
# - **Exam**
# - **Lecture 18:** Instance Segmentation

# %% [markdown]
# # Exam
#
# No lecture content is scheduled for the exam meeting.

# %% [markdown]
# # Lecture 18: Instance Segmentation
#
# Lecture materials will be added here.
