# %% [markdown]
# # Week 12: 3D Scene Representations

# %% [markdown]
# ## Week 12 Lectures
#
# - **Lecture 19:** Implicit 3D Scene Representations and NeRF
# - **Lecture 20:** Explicit 3D Scene Representations and 3D Gaussian Splatting

# %% [markdown]
# # Lecture 19: Implicit 3D Scene Representations and NeRF
#
# Lecture materials will be added here.

# %% [markdown]
# # Lecture 20: Explicit 3D Scene Representations and 3DGS
#
# Lecture materials will be added here.
